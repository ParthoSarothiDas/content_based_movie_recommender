# %%
import pandas as pd
import numpy as np
import json
import re
import nltk
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
movie_df = pd.read_csv('data/movie_df_merged_all.csv')

# %%
movie_df.head(2)
# Out:
#    Unnamed: 0     id                                     title  runtime  \
# 0           0  19995                                    Avatar    162.0
# 1           1    285  Pirates of the Caribbean: At World's End    169.0
#
#   release_date                                           overview  \
# 0   2009-12-10  In the 22nd century, a paraplegic Marine is di...
# 1   2007-05-19  Captain Barbossa, long believed to be dead, ha...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                             keywords  popularity  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...  150.437577
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...  139.082615
#
#    vote_average  vote_count  \
# 0           7.2       11800
# 1           6.9        4500
#
#                                 production_countries  \
# 0  [{"iso_3166_1": "US", "name": "United States o...
# 1  [{"iso_3166_1": "US", "name": "United States o...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
#
#                         poster_path
# 0  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 1  /jGWpG4YhpQwVmjyHEGkxEkeRf0S.jpg

# %%
# New columns -----> release_year
movie_df['release_year'] = movie_df['release_date'].str.split('-').str[0]

# %%
movie_df.drop(columns=['release_date'], inplace=True)

# %%
# overview ------------> Handle missing value
movie_df.dropna(subset=['overview'], inplace = True)

# %%
# overview ------------> convert to List
movie_df.loc[:,'overview'] = movie_df['overview'].apply(lambda x: x.split())

# %%
# genres ---------------> Handle missing value
movie_df.dropna(subset=['genres'], inplace = True)

# %%
movie_df['genres'].isnull().sum()
# Out:
# 0

# %%
# ----->   genres function
def convert(obj):
    L = []
    for i in json.loads(obj):
        L.append(i['name'])
    return L

# %%
# genres ------------> convert to List
movie_df.loc[:,'genres'] = movie_df['genres'].apply(convert)

# %%
# keywords ---------------> Handle missing value
movie_df['keywords'].isnull().sum()
# Out:
# 0

# %%
# keywords ------------> convert to List
movie_df.loc[:,'keywords'] = movie_df['keywords'].apply(convert)

# %%
# popularity --------------> eliminate faction values
movie_df.loc[:, 'popularity'] = movie_df['popularity'].apply(lambda x:round(x))

# %%
# cast -----------------> convert to List ----> First three(3)
def convert_3(obj):
    L = []
    for i in json.loads(obj):
        if len(L) < 3:
           L.append(i['name'])
        else:
            break
    return L

# %%
# cast ------------> convert to List ----> First Three (3)
movie_df.loc[:,'cast']= movie_df['cast'].apply(convert_3)

# %%
# New column ---> star1
def star1(obj):
    if len(obj)>0:
        return obj[0]
    else:
        None

movie_df['star1'] = movie_df['cast'].apply(star1)

# %%
# New column ---> star2
def star2(obj):
    if len(obj)>1:
        return obj[1]
    else:
        None

movie_df['star2'] = movie_df['cast'].apply(star2)

# %%
# New column ---> star3
def star3(obj):
    if len(obj)>2:
        return obj[2]
    else:
        None

movie_df['star3'] = movie_df['cast'].apply(star3)

# %%
# crew column -----Missing Values
movie_df['crew'].isnull().sum()
# Out:
# 0

# %%
def director_fetch(obj):
    L = []
    for i in json.loads(obj):
        if i['job'] == 'Director':
            L.append(i['name'])
            break
    return L

movie_df.loc[:,'crew'] = movie_df['crew'].apply(director_fetch)

# %%
# New column ------> director
movie_df['director'] = movie_df['crew'].apply(lambda x:x[0] if x else None)

# %%
# Remove spaces in values
movie_df.loc[:,'genres'] = movie_df['genres'].apply(lambda x: [re.sub(r"\s+", "", name) for name in x] )
movie_df.loc[:,'keywords'] = movie_df['keywords'].apply(lambda x:[re.sub(r"\s+","",name) for name in x])
movie_df.loc[:,'cast'] = movie_df['cast'].apply(lambda x: [re.sub(r"\s+","",name) for name in x])
movie_df.loc[:,"crew"] = movie_df['crew'].apply(lambda x: [re.sub(r"\s+", "", name) for name in x])

# %%
movie_df.head()
# Out:
#    Unnamed: 0      id                                     title  runtime  \
# 0           0   19995                                    Avatar    162.0
# 1           1     285  Pirates of the Caribbean: At World's End    169.0
# 2           2  206647                                   Spectre    148.0
# 3           3   49026                     The Dark Knight Rises    165.0
# 4           4   49529                               John Carter    132.0
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  popularity  \
# 0  [cultureclash, future, spacewar, spacecolony, ...       150.0
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...       139.0
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...       107.0
# 3  [dccomics, crimefighter, terrorist, secretiden...       112.0
# 4  [basedonnovel, mars, medallion, spacetravel, p...        44.0
#
#    vote_average  vote_count  \
# 0           7.2       11800
# 1           6.9        4500
# 2           6.3        4466
# 3           7.6        9106
# 4           6.1        2124
#
#                                 production_countries  \
# 0  [{"iso_3166_1": "US", "name": "United States o...
# 1  [{"iso_3166_1": "US", "name": "United States o...
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...
# 3  [{"iso_3166_1": "US", "name": "United States o...
# 4  [{"iso_3166_1": "US", "name": "United States o...
#
#                                             cast                crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]
#
#                         poster_path release_year            star1  \
# 0  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg         2009  Sam Worthington
# 1  /jGWpG4YhpQwVmjyHEGkxEkeRf0S.jpg         2007      Johnny Depp
# 2  /672kUEMtTHcaVYSVY4eiHEliHFa.jpg         2015     Daniel Craig
# 3  /hr0L2aueqlP2BYUblTTjmtn0hw4.jpg         2012   Christian Bale
# 4  /lCxz1Yus07QCQQCb6I0Dr3Lmqpx.jpg         2012    Taylor Kitsch
#
#              star2             star3           director
# 0      Zoe Saldana  Sigourney Weaver      James Cameron
# 1    Orlando Bloom   Keira Knightley     Gore Verbinski
# 2  Christoph Waltz       Léa Seydoux         Sam Mendes
# 3    Michael Caine       Gary Oldman  Christopher Nolan
# 4     Lynn Collins   Samantha Morton     Andrew Stanton

# %%
# Combined all tags
movie_df['tags'] = movie_df['overview'] + movie_df['genres'] + movie_df['keywords'] + movie_df['cast'] + movie_df['crew']

# %%
# Drop unnecessarty columns
movie_df.drop(columns=['genres','keywords','cast','crew'], inplace=True)

# %%
movie_df['overview'] = movie_df['overview'].apply(lambda x:" ".join(x))

# %%
movie_df.loc[:,'tags']= movie_df['tags'].apply(lambda x:" ".join(x))

# %%
movie_df.head(3)
# Out:
#    Unnamed: 0      id                                     title  runtime  \
# 0           0   19995                                    Avatar    162.0
# 1           1     285  Pirates of the Caribbean: At World's End    169.0
# 2           2  206647                                   Spectre    148.0
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...       150.0
# 1  Captain Barbossa, long believed to be dead, ha...       139.0
# 2  A cryptic message from Bond’s past sends him o...       107.0
#
#    vote_average  vote_count  \
# 0           7.2       11800
# 1           6.9        4500
# 2           6.3        4466
#
#                                 production_countries  \
# 0  [{"iso_3166_1": "US", "name": "United States o...
# 1  [{"iso_3166_1": "US", "name": "United States o...
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...
#
#                         poster_path release_year            star1  \
# 0  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg         2009  Sam Worthington
# 1  /jGWpG4YhpQwVmjyHEGkxEkeRf0S.jpg         2007      Johnny Depp
# 2  /672kUEMtTHcaVYSVY4eiHEliHFa.jpg         2015     Daniel Craig
#
#              star2             star3        director  \
# 0      Zoe Saldana  Sigourney Weaver   James Cameron
# 1    Orlando Bloom   Keira Knightley  Gore Verbinski
# 2  Christoph Waltz       Léa Seydoux      Sam Mendes
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...

# %% [markdown]
# ### Note: 1
# ```
#    ['partho', 'abhik'] -------> 'partho abhik' ---------> ['partho','abhik']
#
# a= ['partho','abhik']
# b= " ".join(a) --> output: 'partho abhik'
# b.split() -------> output: ['partho','abhik']
# ```

# %%
# Convert to ----------------> lowercase
movie_df.loc[:,'tags'] = movie_df['tags'].apply(lambda x:x.lower())

# %%
# stremmer -------------------->

ps = PorterStemmer()

# %%
# -----> 
def word_stem(text):
    stemd_text_list = []
    for i in text.split():
        stemd_text_list.append(ps.stem(i))
    return " ".join(stemd_text_list)

# %%
# -------> Stemmer
movie_df.loc[:,'tags'] = movie_df['tags'].apply(word_stem)

# %%
movie_df['tags'][0]
# Out:
# 'in the 22nd century, a parapleg marin is dispatch to the moon pandora on a uniqu mission, but becom torn between follow order and protect an alien civilization. action adventur fantasi sciencefict cultureclash futur spacewar spacecoloni societi spacetravel futurist romanc space alien tribe alienplanet cgi marin soldier battl loveaffair antiwar powerrel mindandsoul 3d samworthington zoesaldana sigourneyweav jamescameron'

# %%
# Vectorization ---------------->

cv = CountVectorizer(max_features=5000, stop_words='english')

# %%
vectors = cv.fit_transform(movie_df['tags']).toarray()

# %%
# Cosine_similarity
similarity_vector = cosine_similarity(vectors)

# %%
## Function for extract -----------> movie list 
def recommended_movie(movie):
    movie_index = movie_df[movie_df['title']  == movie].index[0]
    similarity_row = similarity_vector[movie_index]
    recommended_movie_index = np.argsort(similarity_row)[::-1][1:10]
    recommended_movie_list = []
    for i in recommended_movie_index:
        recommended_movie_list.append(movie_df['title'].loc[i])
    return recommended_movie_list

# %%
recommended_movie('Swordfish')
# Out:
# ['Hackers',
#  'I Am Wrath',
#  'Pocketful of Miracles',
#  'Mission: Impossible II',
#  'Mean Machine',
#  'Ghost Dog: The Way of the Samurai',
#  'Taken 2',
#  'The Sentinel',
#  'Akira']

# %%
movie_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# Export files
movie_df.to_csv('data/movie_df_processed.csv')

# %%
# save similarity_vector
np.save('data/similarity_vector.npy', similarity_vector)

# %%
# All movie List

movie_list = sorted(movie_df['title'].unique())

# %%
movie_df.head()
# Out:
#        id                                     title  runtime  \
# 0   19995                                    Avatar    162.0
# 1     285  Pirates of the Caribbean: At World's End    169.0
# 2  206647                                   Spectre    148.0
# 3   49026                     The Dark Knight Rises    165.0
# 4   49529                               John Carter    132.0
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...       150.0
# 1  Captain Barbossa, long believed to be dead, ha...       139.0
# 2  A cryptic message from Bond’s past sends him o...       107.0
# 3  Following the death of District Attorney Harve...       112.0
# 4  John Carter is a war-weary, former military ca...        44.0
#
#    vote_average  vote_count  \
# 0           7.2       11800
# 1           6.9        4500
# 2           6.3        4466
# 3           7.6        9106
# 4           6.1        2124
#
#                                 production_countries  \
# 0  [{"iso_3166_1": "US", "name": "United States o...
# 1  [{"iso_3166_1": "US", "name": "United States o...
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...
# 3  [{"iso_3166_1": "US", "name": "United States o...
# 4  [{"iso_3166_1": "US", "name": "United States o...
#
#                         poster_path release_year            star1  \
# 0  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg         2009  Sam Worthington
# 1  /jGWpG4YhpQwVmjyHEGkxEkeRf0S.jpg         2007      Johnny Depp
# 2  /672kUEMtTHcaVYSVY4eiHEliHFa.jpg         2015     Daniel Craig
# 3  /hr0L2aueqlP2BYUblTTjmtn0hw4.jpg         2012   Christian Bale
# 4  /lCxz1Yus07QCQQCb6I0Dr3Lmqpx.jpg         2012    Taylor Kitsch
#
#              star2             star3           director  \
# 0      Zoe Saldana  Sigourney Weaver      James Cameron
# 1    Orlando Bloom   Keira Knightley     Gore Verbinski
# 2  Christoph Waltz       Léa Seydoux         Sam Mendes
# 3    Michael Caine       Gary Oldman  Christopher Nolan
# 4     Lynn Collins   Samantha Morton     Andrew Stanton
#
#                                                 tags
# 0  in the 22nd century, a parapleg marin is dispa...
# 1  captain barbossa, long believ to be dead, ha c...
# 2  a cryptic messag from bond’ past send him on a...
# 3  follow the death of district attorney harvey d...
# 4  john carter is a war-weary, former militari ca...

# %%
## Function for extract ----------> DataFrame
def recommended_movie_df(movie):
    movie_index = movie_df[movie_df['title']  == movie].index[0]
    similarity_row = similarity_vector[movie_index]
    recommended_movie_index = np.argsort(similarity_row)[::-1][1:10]
    
    df_list = [] 
    for i in recommended_movie_index:
        df_temp = movie_df.loc[[i]]
        df_list.append(df_temp)
    df = pd.concat(df_list, ignore_index=True)
    return df

# %%
recom_df = recommended_movie_df('Avatar')
recom_df.head(20)
# Out:
#       id                        title  runtime  \
# 0    440  Aliens vs Predator: Requiem     94.0
# 1    679                       Aliens    137.0
# 2  17663         Anne of Green Gables    199.0
# 3    602             Independence Day    145.0
# 4   7450                   Titan A.E.     94.0
# 5  44943          Battle: Los Angeles    116.0
# 6  34851                    Predators    107.0
# 7  11551               Small Soldiers    110.0
# 8  76757            Jupiter Ascending    124.0
#
#                                             overview  popularity  \
# 0  A sequel to 2004's Alien vs. Predator, the ico...        39.0
# 1  When Ripley's lifepod is found by a salvage cr...        68.0
# 2  At the turn of the century on Prince Edward Is...         9.0
# 3  On July 2, a giant alien mothership enters orb...        60.0
# 4  A young man finds out that he holds the key to...        14.0
# 5  The Earth is attacked by unknown forces. As pe...        49.0
# 6  A mercenary reluctantly leads a motley crew of...        48.0
# 7  When missile technology is used to enhance toy...        23.0
# 8  In a universe where human genetic material is ...        85.0
#
#    vote_average  vote_count  \
# 0           4.9         740
# 1           7.7        3220
# 2           8.2          68
# 3           6.7        3260
# 4           6.3         313
# 5           5.5        1448
# 6           6.0        1206
# 7           6.2         511
# 8           5.2        2768
#
#                                 production_countries  \
# 0  [{"iso_3166_1": "US", "name": "United States o...
# 1  [{"iso_3166_1": "GB", "name": "United Kingdom"...
# 2  [{"iso_3166_1": "US", "name": "United States o...
# 3  [{"iso_3166_1": "US", "name": "United States o...
# 4  [{"iso_3166_1": "US", "name": "United States o...
# 5  [{"iso_3166_1": "US", "name": "United States o...
# 6  [{"iso_3166_1": "US", "name": "United States o...
# 7  [{"iso_3166_1": "US", "name": "United States o...
# 8  [{"iso_3166_1": "US", "name": "United States o...
#
#                         poster_path release_year             star1  \
# 0  /jCyJN1vj8jqJJ0vNw4hDH2KlySO.jpg         2007   Steven Pasquale
# 1  /r1x5JGpyqZU8PYhbs4UcrO1Xb6x.jpg         1986  Sigourney Weaver
# 2  /z1owlDzKO3DQpFKNFBnuQlPF891.jpg         1985     Megan Follows
# 3  /p0BPQGSPoSa8Ml0DAf2mB2kCU0R.jpg         1996        Will Smith
# 4  /el2iHk3LTJWfEnwrvcRkvWY501G.jpg         2000        Matt Damon
# 5  /jloyGeVYZSxM9zsLFvVOWuj2ey4.jpg         2011     Aaron Eckhart
# 6  /54LZIRznS0Zjn7ZDXrsGVe3HXei.jpg         2010      Topher Grace
# 7  /2nuUjSzHsoYlRvTPmLo7m7gCQry.jpg         1998     Gregory Smith
# 8  /xzQ25m9vrdyvpLX74T3B3KB40Ou.jpg         2015        Mila Kunis
#
#               star2               star3            director  \
# 0  Reiko Aylesworth          John Ortiz       Colin Strause
# 1     Michael Biehn         James Remar       James Cameron
# 2  Colleen Dewhurst  Richard Farnsworth      Kevin Sullivan
# 3      Bill Pullman       Jeff Goldblum     Roland Emmerich
# 4      Bill Pullman      Drew Barrymore        Gary Goldman
# 5   Ramón Rodríguez       Will Rothhaar  Jonathan Liebesman
# 6       Alice Braga  Laurence Fishburne        Nimród Antal
# 7     Kirsten Dunst         Denis Leary           Joe Dante
# 8    Channing Tatum           Sean Bean     Lilly Wachowski
#
#                                                 tags
# 0  a sequel to 2004' alien vs. predator, the icon...
# 1  when ripley' lifepod is found by a salvag crew...
# 2  at the turn of the centuri on princ edward isl...
# 3  on juli 2, a giant alien mothership enter orbi...
# 4  a young man find out that he hold the key to r...
# 5  the earth is attack by unknown forces. as peop...
# 6  a mercenari reluctantli lead a motley crew of ...
# 7  when missil technolog is use to enhanc toy act...
# 8  in a univers where human genet materi is the m...

# %%
recom_df['poster_path'][0]
# Out:
# '/jCyJN1vj8jqJJ0vNw4hDH2KlySO.jpg'

# %%
# Poster_path 
BASE_URL = "https://image.tmdb.org/t/p/w500"
BASE_URL+recom_df['poster_path'][0]
# Out:
# 'https://image.tmdb.org/t/p/w500/jCyJN1vj8jqJJ0vNw4hDH2KlySO.jpg'

# %%
movie= 'Avatar'

# %%
df = movie_df[movie_df['title'] == movie]
df['title'][0]
# Out:
# 'Avatar'
